# %% [markdown]
# <H1 style="text-align: center">ECMM422 - Machine Learning Test (Filter testing)</H1>
# <H2 style="text-align: center">Virtual User Preference</H2>

# %% [markdown]
# <div class="alert alert-info">
#  This notebook shows the user of a chosen machine learning techique on virtual users. In order to get their specified images.
#  </div>

# %%
# !pip install -q import_ipynb

# %%
import import_ipynb

# for plotting functions
import matplotlib.pyplot as plt

# for loading the data we will use
from ECMM428_Individual_Research_Project import graph_reader,get_data_labels,machine_learing_algorithm,virtual_user1,virtual_user2,virtual_user3,virtual_user4,virtual_user5


import warnings
warnings.filterwarnings("ignore")
# Out:
# importing Jupyter notebook from ECMM428_Individual_Research_Project.ipynb
# ...

# %%
# Plot formatting
# plt.rcParams['font.size'] = 6

  # Run program IMPORTANT
if __name__ == "__main__":
    perl = "elephant" # The main peference HERE
    
    try:
        # Load in data
        graphs = graph_reader(perl)
    except:
        # Create data
        create_selected_graphs(perl)
        # Load in data
        graphs = graph_reader(perl) 

    favourite = [virtual_user1,virtual_user2,virtual_user3,virtual_user4,virtual_user5]
    for user_preference in range(len(favourite)):
        X,labels = get_data_labels(graphs,favourite[user_preference])
        print("\n VIRTUAL USER {}:\n".format(user_preference+1))
        model = machine_learing_algorithm(X,labels)

#         visualize_network(chosen_one,image=True)
# Out:
# 2147it [00:01, 1416.30it/s]
# 100%|██████████| 2145/2145 [00:00<00:00, 55147.28it/s]
#  VIRTUAL USER 1:
#
# Recall Baseline: 1.0 Test: 1.0 Train: 1.0
# Precision Baseline: 1.0 Test: 1.0 Train: 1.0
# Roc Baseline: 0.5 Test: 1.0 Train: 1.0
# Ground truth result:
#               precision    recall  f1-score   support
#
#      Dislike       1.00      1.00      1.00         4
#         Like       1.00      1.00      1.00      1497
#
#     accuracy                           1.00      1501
#    macro avg       1.00      1.00      1.00      1501
# weighted avg       1.00      1.00      1.00      1501
#
# Testing result:
#               precision    recall  f1-score   support
#
#      Dislike       1.00      1.00      1.00         2
#         Like       1.00      1.00      1.00       642
#
#     accuracy                           1.00       644
#    macro avg       1.00      1.00      1.00       644
# weighted avg       1.00      1.00      1.00       644
#
# Accuracy Score: 1.0
# ...
